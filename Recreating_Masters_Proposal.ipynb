# %% [markdown]
# <a href="https://colab.research.google.com/github/ovisaha5/DataProcessingSP22/blob/main/Recreating_Masters_Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Avijit Saha
# ###Recreating the Excellent Visualization Proposal

# %%
import pandas as pa
df= pa.read_csv('https://raw.githubusercontent.com/ovisaha5/DataProcessingSP22/main/covid-vaccinations-vs-gdp-per-capita.csv')
df.head(10)
# Out:
#         Entity      Code         Day  total_vaccinations_per_hundred  \
# 0     Abkhazia  OWID_ABK  2020-01-21                             NaN
# 1  Afghanistan       AFG  2021-02-22                            0.00
# 2  Afghanistan       AFG  2021-02-28                            0.02
# 3  Afghanistan       AFG  2021-03-16                            0.14
# 4  Afghanistan       AFG  2021-04-07                            0.30
# 5  Afghanistan       AFG  2021-04-22                            0.60
# 6  Afghanistan       AFG  2021-05-11                            1.27
# 7  Afghanistan       AFG  2021-05-20                            1.38
# 8  Afghanistan       AFG  2021-05-24                            1.44
# 9  Afghanistan       AFG  2021-05-26                            1.48
#
#    GDP per capita, PPP (constant 2011 international $)    Year  Year.1  \
# 0                                                NaN       NaN  2015.0
# ...

# %% [markdown]
# I am recreating the covid-19 vactination vs GDP per capita by countries.
#
# Here is the link, https://ourworldindata.org/grapher/covid-vaccinations-vs-gdp-per-capita
#
# Here is the visualization which I will try to recreate,
# ![Covid-19 vs GDP](https://media.springernature.com/full/springer-static/image/art%3A10.1038%2Fs41562-021-01122-8/MediaObjects/41562_2021_1122_Fig2_HTML.png?as=webp)

# %% [markdown]
# Here is link where I get the data from the download section, https://ourworldindata.org/grapher/covid-vaccinations-vs-gdp-per-capita

# %% [markdown]
# I think this is an excellent visualization where it present a big data set in a small place. It is well decribed and the choiche of plot in this visualization explaining a lot of thing by its color. So I think it is an example of excellent visualisation.
#
# In this visualization it describe the country GDP along with the continent which is basically presenting by its color and also another variable is covid vaccination per 100 people.
#
# This will be a challenge for me to recreate this visualization to diiferent variables and add them in to plot and present them with the name of the locations.
