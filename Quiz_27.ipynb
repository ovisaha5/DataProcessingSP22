# %% [markdown]
# <a href="https://colab.research.google.com/github/ovisaha5/DataProcessingSP22/blob/main/Quiz_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Quiz 27
# ##Proportions
# ####Avijit Saha

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %%
data=df.groupby('workout_type').workout_type.agg('count')
data
# Out:
# workout_type
# Cricket            93
# Freestyle          96
# Indoor Cycling     80
# Open Water         91
# Outdoor Cycling    85
# Outdoor Running    81
# Pool Swimming      94
# Trail Run          90
# Treadmill          98
# Trekking           94
# Walking            98
# Name: workout_type, dtype: int64

# %%
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:d}".format(absolute)
plt.pie(x=data,labels = data.index,colors = ( "orange", "cyan", "brown",
          "grey", "beige"),autopct=lambda pct: func(pct, data))
                            
plt.show()

# %%
from statsmodels.graphics.mosaicplot import mosaic
df2 = df[(df.activity_day == '2022-01-01')|(df.activity_day == '2022-01-02')|(df.activity_day == '2022-01-03')]
ax = mosaic(df2, [ 'workout_type','activity_day'])
plt.figsize=(15, 10)
plt.show()

# %% [markdown]
# Mosaic is able to define two or more group of categorial variable at the same time, where bar chart and pie chart can do for one group at a time. Here we have two category one is by date and another one is by workout type. In pie chart or bar chart they are only be able to show by one category at a time.
