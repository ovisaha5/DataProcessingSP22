# %% [markdown]
# <a href="https://colab.research.google.com/github/ovisaha5/DataProcessingSP22/blob/main/Quiz_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Quiz_11_Twitter
#
# ####Avijit Saha

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 1.4 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %%
import twitter
import config

CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %%
WORLD_WOE_ID = 1
world_trends = mathcs_twitter_api.trends.place(_id=WORLD_WOE_ID)
for i in range(10):
    print(world_trends[0]['trends'][i]['name'])
# Out:
# #isolitiignoti
# #JohnsonOut14
# #akaryakıt
# Notifications
# #TPMP
# #UltimateSummit4
# Keir Starmer
# Euphoria
# Sercan
# Lovie Smith

# %%
import json
q = '#LataMangeshkar'
count = 1000
search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError:
      break

    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']


print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 3499,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1479418842619080704/KVEE4qAx_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1479418842619080704/KVEE4qAx_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/620025382/1640615288",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 14:18:23 +0000 2022",
#             "id": 1490691415340302336,
#             "id_str": "1490691415340302336",
#             "text": "\u0d05\u0d28\u0d36\u0d4d\u0d35\u0d30 \u0d17\u0d3e\u0d2f\u0d3f\u0d15\u0d2f\u0d4d\u0d15\u0d4d\u0d15\u0d4d \u0d38\u0d4d\u0d31\u0d4d\u0d31\u0d3e\u0d7c \u0d38\u0d3f\u0d19\u0d4d\u0d19\u0d7c \u0d26\u0d3f \u0d0e\u0d2a\u0d3f\u0d15\u0d4d \u0d37\u0d4b\u0d2f\u0d41\u0d1f\u0d46 \u0d2a\u0d4d\u0d30\u0d23\u0d3e\u0d2e\u0d02 https://t.co/F2fkkP2vh7 via @YouTube #LataMangeshkar #KSChithra #KSChitra",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "LataMangeshkar",
#                         "indices": [
#                             95,
#                             110
#                         ]
#                     },
#                     {
#                         "text": "KSChithra",
#                         "indices": [
#                             111,
#                             121
#                         ]
#                     },
#                     {
#                         "text": "KSChitra",
#                         "indices": [
#                             122,
#                             131
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "YouTube",
#                         "name": "YouTube",
#                         "id": 10228272,
#                         "id_str": "10228272",
#                         "indices": [
#                             86,
#                             94
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/F2fkkP2vh7",
#                         "expanded_url": "https://youtu.be/6ggNRFJhywg",
#                         "display_url": "youtu.be/6ggNRFJhywg",
#                         "indices": [
#                             58,
#                             81
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "ml",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 2343265680,
#                 "id_str": "2343265680",
#                 "name": "K S Chithra",
#                 "screen_name": "KSChithra",
#                 "location": "Chennai, India",
#                 "description": "Playback Singer https://t.co/V4Xf78JnzW",
#                 "url": "https://t.co/i62eqwIHdO",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/i62eqwIHdO",
#                                 "expanded_url": "https://www.youtube.com/KSChithra",
#                                 "display_url": "youtube.com/KSChithra",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/V4Xf78JnzW",
#                                 "expanded_url": "http://www.instagram.com/kschithra",
#                                 "display_url": "instagram.com/kschithra",
#                                 "indices": [
#                                     16,
#                                     39
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 89708,
#                 "friends_count": 23,
#                 "listed_count": 53,
#                 "created_at": "Fri Feb 14 08:13:15 +0000 2014",
#                 "favourites_count": 1095,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 7439,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "FF6699",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme11/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme11/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1377325427660779525/VKEIBbvE_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1377325427660779525/VKEIBbvE_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2343265680/1590085048",
#                 "profile_link_color": "B40B43",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "E5507E",
#                 "profile_text_color": "362720",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 7,
#             "favorite_count": 35,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "ml"
#         },
#         "is_quote_status": false,
#         "retweet_count": 7,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": true,
#         "lang": "ml"
#     },
#     {
#         "created_at": "Mon Feb 07 21:04:39 +0000 2022",
#         "id": 1490793656059629569,
#         "id_str": "1490793656059629569",
#         "text": "RT @PIB_India: Meri Awaaz Hi Pehchaan Hain....\nGar Yaad Rahe...\n\nA voice that comes once in a century, #LataMangeshkar is an emotion that w\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "LataMangeshkar",
#                     "indices": [
#                         103,
#                         118
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "PIB_India",
#                     "name": "PIB India",
#                     "id": 231033118,
#                     "id_str": "231033118",
#                     "indices": [
#                         3,
#                         13
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1353680186441658368,
#             "id_str": "1353680186441658368",
#             "name": "\ud83c\udf10 The Consular Association in Wales\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc77\udb40\udc6c\udb40\udc73\udb40\udc7f",
#             "screen_name": "ConsularWales",
#             "location": "Wales",
#             "description": "We are an association of consular officers in Wales. We work to support the countries we represent and build bridges between them and Wales. \n#Consular #Wales",
#             "url": "https://t.co/3q3jSlE221",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/3q3jSlE221",
#                             "expanded_url": "https://consularwales.org.uk/",
#                             "display_url": "consularwales.org.uk",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 168,
#             "friends_count": 1222,
#             "listed_count": 1,
#             "created_at": "Mon Jan 25 12:25:57 +0000 2021",
#             "favourites_count": 940,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 749,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1353693933533073409/wcQSDfty_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1353693933533073409/wcQSDfty_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1353680186441658368/1634174993",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 12:25:09 +0000 2022",
#             "id": 1490662916349378570,
#             "id_str": "1490662916349378570",
#             "text": "Meri Awaaz Hi Pehchaan Hain....\nGar Yaad Rahe...\n\nA voice that comes once in a century, #LataMangeshkar is an emoti\u2026 https://t.co/XHJzxNbP31",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "LataMangeshkar",
#                         "indices": [
#                             88,
#                             103
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/XHJzxNbP31",
#                         "expanded_url": "https://twitter.com/i/web/status/1490662916349378570",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 231033118,
#                 "id_str": "231033118",
#                 "name": "PIB India",
#                 "screen_name": "PIB_India",
#                 "location": "New Delhi",
#                 "description": "Press Information Bureau. Nodal agency for communicating to media on behalf of #Government of #India. In Hindi: @pibhindi For Fact Check: @PIBFactCheck",
#                 "url": "https://t.co/qD9b41B2is",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/qD9b41B2is",
#                                 "expanded_url": "http://pib.gov.in",
#                                 "display_url": "pib.gov.in",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2553644,
#                 "friends_count": 318,
#                 "listed_count": 3686,
#                 "created_at": "Mon Dec 27 11:55:36 +0000 2010",
#                 "favourites_count": 2123,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 259575,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "07090B",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme6/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme6/bg.gif",
#                 "profile_background_tile": true,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1313803439340548097/jcQYJdhp_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1313803439340548097/jcQYJdhp_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/231033118/1638177893",
#                 "profile_link_color": "663366",
#                 "profile_sidebar_border_color": "BFBFBF",
#                 "profile_sidebar_fill_color": "C9C9C9",
#                 "profile_text_color": "1C1F23",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 19,
#             "favorite_count": 51,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 19,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Mon Feb 07 21:04:39 +0000 2022",
#         "id": 1490793653564248064,
#         "id_str": "1490793653564248064",
#         "text": "RT @RituPri61677926: \u0932\u0924\u093e \u091c\u0940 \u0915\u093e \u0915\u0947\u0935\u0932 \u0928\u093e\u092e \"\u0932\u0924\u093e\" \u0925\u093e \u0932\u0947\u0915\u093f\u0928 \u0935\u094d\u092f\u0915\u094d\u0924\u093f\u0924\u094d\u0935 \u0915\u093f\u0938\u0940 \u0935\u091f \u0935\u0943\u0915\u094d\u0937 \u0915\u0947 \u0938\u093e\u092e\u093e\u0928 \u0925\u093e..\n \u092c\u0939\u0941\u0924 \u092f\u093e\u0926 \u0906\u0913\u0917\u0940 \"\u0926\u0940\u0926\u0940\" #LataMangeshkar \ud83d\ude4f\ud83d\ude4f",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "LataMangeshkar",
#                     "indices": [
#                         116,
#                         131
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "RituPri61677926",
#                     "name": "Ritu Priya",
#                     "id": 1257985348723806208,
#                     "id_str": "1257985348723806208",
#                     "indices": [
#                         3,
#                         19
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "hi",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1438412180748050434,
#             "id_str": "1438412180748050434",
#             "name": "\u0905\u0928\u093f\u0932 \u0938\u093f\u0902\u0939 KRT 101%FB",
#             "screen_name": "SuryaSi99128957",
#             "location": "",
#             "description": "\u0926\u0947\u0936 \u0939\u093f\u0924 \u0938\u0930\u094d\u0935\u094b\u092a\u0930\u093f \ud83d\udea9\ud83d\udea9\ud83d\udea9",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1651,
#             "friends_count": 2259,
#             "listed_count": 0,
#             "created_at": "Thu Sep 16 08:01:09 +0000 2021",
#             "favourites_count": 2331,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 7415,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1490404790295154688/7LzHmbDc_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1490404790295154688/7LzHmbDc_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1438412180748050434/1644175898",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 03:59:37 +0000 2022",
#             "id": 1490535694925983753,
#             "id_str": "1490535694925983753",
#             "text": "\u0932\u0924\u093e \u091c\u0940 \u0915\u093e \u0915\u0947\u0935\u0932 \u0928\u093e\u092e \"\u0932\u0924\u093e\" \u0925\u093e \u0932\u0947\u0915\u093f\u0928 \u0935\u094d\u092f\u0915\u094d\u0924\u093f\u0924\u094d\u0935 \u0915\u093f\u0938\u0940 \u0935\u091f \u0935\u0943\u0915\u094d\u0937 \u0915\u0947 \u0938\u093e\u092e\u093e\u0928 \u0925\u093e..\n \u092c\u0939\u0941\u0924 \u092f\u093e\u0926 \u0906\u0913\u0917\u0940 \"\u0926\u0940\u0926\u0940\" #LataMangeshkar \ud83d\ude4f\ud83d\ude4f",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "LataMangeshkar",
#                         "indices": [
#                             95,
#                             110
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "hi",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1257985348723806208,
#                 "id_str": "1257985348723806208",
#                 "name": "Ritu Priya",
#                 "screen_name": "RituPri61677926",
#                 "location": "India",
#                 "description": "\u0906\u092a \u0915\u094c\u0928 \u0939\u0948\u0902 \u092e\u0948\u0902 \u0928\u0939\u0940\u0902 \u091c\u093e\u0928\u0924\u0940,\u092e\u0948\u0902 \u0915\u094c\u0928 \u0939\u0942\u0901 \u0906\u092a \u0928\u0939\u0940\u0902 \u091c\u093e\u0928\u0924\u0947\ud83e\udd14\n\u0905\u0917\u0930 \u0939\u093f\u0902\u0926\u0941\u0924\u094d\u0935,\u0930\u093e\u0937\u094d\u091f\u094d\u0930 \u0915\u0947 \u0932\u093f\u090f \u0906\u092a \u0916\u0921\u093c\u0947 \u0939\u0948\u0902\ud83d\udcaa\n\u0924\u094b \u0906\u092a \u092e\u0947\u0930\u0947 \u0905\u092a\u0928\u0947 \u0939\u0948\u0902\ud83d\ude4f\n\ud83c\uddee\ud83c\uddf3 \u0935\u0928\u094d\u0926\u0947 \u092e\u093e\u0924\u0930\u092e\u094d \ud83c\uddee\ud83c\uddf3",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 8158,
#                 "friends_count": 461,
#                 "listed_count": 0,
#                 "created_at": "Wed May 06 10:48:04 +0000 2020",
#                 "favourites_count": 11778,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 7343,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1257992075624083459/RFuu4HPk_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1257992075624083459/RFuu4HPk_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1257985348723806208/1588763788",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 22,
#             "favorite_count": 81,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "hi"
#         },
#         "is_quote_status": false,
#         "retweet_count": 22,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "hi"
#     },
#     {
#         "created_at": "Mon Feb 07 21:04:32 +0000 2022",
#         "id": 1490793627127545857,
#         "id_str": "1490793627127545857",
#         "text": "RT @SabharwalAnkush: #LataMangeshkar\nTribute to Nightangle of India. https://t.co/I3r4twpb8h",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "LataMangeshkar",
#                     "indices": [
#                         21,
#                         36
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "SabharwalAnkush",
#                     "name": "Ankush Sabharwal",
#                     "id": 128827533,
#                     "id_str": "128827533",
#                     "indices": [
#                         3,
#                         19
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490396168865521665,
#                     "id_str": "1490396168865521665",
#                     "indices": [
#                         69,
#                         92
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                     "url": "https://t.co/I3r4twpb8h",
#                     "display_url": "pic.twitter.com/I3r4twpb8h",
#                     "expanded_url": "https://twitter.com/SabharwalAnkush/status/1490396693514182661/video/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490396693514182661,
#                     "source_status_id_str": "1490396693514182661",
#                     "source_user_id": 128827533,
#                     "source_user_id_str": "128827533"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490396168865521665,
#                     "id_str": "1490396168865521665",
#                     "indices": [
#                         69,
#                         92
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                     "url": "https://t.co/I3r4twpb8h",
#                     "display_url": "pic.twitter.com/I3r4twpb8h",
#                     "expanded_url": "https://twitter.com/SabharwalAnkush/status/1490396693514182661/video/1",
#                     "type": "video",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490396693514182661,
#                     "source_status_id_str": "1490396693514182661",
#                     "source_user_id": 128827533,
#                     "source_user_id_str": "128827533",
#                     "video_info": {
#                         "aspect_ratio": [
#                             16,
#                             9
#                         ],
#                         "duration_millis": 19328,
#                         "variants": [
#                             {
#                                 "bitrate": 2176000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/vid/1280x720/DfyUhDN4HVxyWTUF.mp4?tag=12"
#                             },
#                             {
#                                 "bitrate": 256000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/vid/480x270/vHA1G_EPpuHVGIY7.mp4?tag=12"
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/pl/KBap3uLPAr64hOif.m3u8?tag=12&container=fmp4"
#                             },
#                             {
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/vid/640x360/6eIXM0kb6SF_rIu-.mp4?tag=12"
#                             }
#                         ]
#                     },
#                     "additional_media_info": {
#                         "monetizable": false,
#                         "source_user": {
#                             "id": 128827533,
#                             "id_str": "128827533",
#                             "name": "Ankush Sabharwal",
#                             "screen_name": "SabharwalAnkush",
#                             "location": "Metaverse",
#                             "description": "Founder/CEO of CoRover | 500 Million+ user base | World\u2019s first & the highest ROI delivering human-centric Conversational AI platform | VC Funded | @CoRover_App",
#                             "url": "https://t.co/UWWb4LJYjG",
#                             "entities": {
#                                 "url": {
#                                     "urls": [
#                                         {
#                                             "url": "https://t.co/UWWb4LJYjG",
#                                             "expanded_url": "https://www.linkedin.com/in/ankushsabharwal",
#                                             "display_url": "linkedin.com/in/ankushsabha\u2026",
#                                             "indices": [
#                                                 0,
#                                                 23
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 "description": {
#                                     "urls": []
#                                 }
#                             },
#                             "protected": false,
#                             "followers_count": 10011,
#                             "friends_count": 1882,
#                             "listed_count": 13,
#                             "created_at": "Fri Apr 02 09:09:26 +0000 2010",
#                             "favourites_count": 930,
#                             "utc_offset": null,
#                             "time_zone": null,
#                             "geo_enabled": true,
#                             "verified": true,
#                             "statuses_count": 940,
#                             "lang": null,
#                             "contributors_enabled": false,
#                             "is_translator": false,
#                             "is_translation_enabled": false,
#                             "profile_background_color": "C0DEED",
#                             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_tile": false,
#                             "profile_image_url": "http://pbs.twimg.com/profile_images/1091664164467036160/ahF5rGBQ_normal.jpg",
#                             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1091664164467036160/ahF5rGBQ_normal.jpg",
#                             "profile_banner_url": "https://pbs.twimg.com/profile_banners/128827533/1619704533",
#                             "profile_link_color": "1DA1F2",
#                             "profile_sidebar_border_color": "C0DEED",
#                             "profile_sidebar_fill_color": "DDEEF6",
#                             "profile_text_color": "333333",
#                             "profile_use_background_image": true,
#                             "has_extended_profile": true,
#                             "default_profile": true,
#                             "default_profile_image": false,
#                             "following": false,
#                             "follow_request_sent": false,
#                             "notifications": false,
#                             "translator_type": "none",
#                             "withheld_in_countries": []
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 92504435,
#             "id_str": "92504435",
#             "name": "Beepz \ud83c\uddee\ud83c\uddf3",
#             "screen_name": "bpn_25",
#             "location": "mumbai",
#             "description": "Male",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 690,
#             "friends_count": 2604,
#             "listed_count": 2,
#             "created_at": "Wed Nov 25 11:47:29 +0000 2009",
#             "favourites_count": 103809,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 59270,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1468676221705748482/Adj8jfY8_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1468676221705748482/Adj8jfY8_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/92504435/1570553301",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Sun Feb 06 18:47:16 +0000 2022",
#             "id": 1490396693514182661,
#             "id_str": "1490396693514182661",
#             "text": "#LataMangeshkar\nTribute to Nightangle of India. https://t.co/I3r4twpb8h",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "LataMangeshkar",
#                         "indices": [
#                             0,
#                             15
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490396168865521665,
#                         "id_str": "1490396168865521665",
#                         "indices": [
#                             48,
#                             71
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                         "url": "https://t.co/I3r4twpb8h",
#                         "display_url": "pic.twitter.com/I3r4twpb8h",
#                         "expanded_url": "https://twitter.com/SabharwalAnkush/status/1490396693514182661/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490396168865521665,
#                         "id_str": "1490396168865521665",
#                         "indices": [
#                             48,
#                             71
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490396168865521665/pu/img/mw0J8ie6O8jTrPsU.jpg",
#                         "url": "https://t.co/I3r4twpb8h",
#                         "display_url": "pic.twitter.com/I3r4twpb8h",
#                         "expanded_url": "https://twitter.com/SabharwalAnkush/status/1490396693514182661/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 19328,
#                             "variants": [
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/vid/1280x720/DfyUhDN4HVxyWTUF.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/vid/480x270/vHA1G_EPpuHVGIY7.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/pl/KBap3uLPAr64hOif.m3u8?tag=12&container=fmp4"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490396168865521665/pu/vid/640x360/6eIXM0kb6SF_rIu-.mp4?tag=12"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 128827533,
#                 "id_str": "128827533",
#                 "name": "Ankush Sabharwal",
#                 "screen_name": "SabharwalAnkush",
#                 "location": "Metaverse",
#                 "description": "Founder/CEO of CoRover | 500 Million+ user base | World\u2019s first & the highest ROI delivering human-centric Conversational AI platform | VC Funded | @CoRover_App",
#                 "url": "https://t.co/UWWb4LJYjG",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/UWWb4LJYjG",
#                                 "expanded_url": "https://www.linkedin.com/in/ankushsabharwal",
#                                 "display_url": "linkedin.com/in/ankushsabha\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 10011,
#                 "friends_count": 1882,
#                 "listed_count": 13,
#                 "created_at": "Fri Apr 02 09:09:26 +0000 2010",
#                 "favourites_count": 930,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 940,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
# ...
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 8045,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1469360990403710977/LEVu_GDP_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1469360990403710977/LEVu_GDP_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1266724545035206656/1590923797",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 06:04:41 +0000 2022",
#             "id": 1490567172149575681,
#             "id_str": "1490567172149575681",
#             "text": "No, #ShahRukhKhan did not spit near #LataMangeshkar\u2019s mortal remains; he read \u2018dua and blew the air\u2019 https://t.co/0A9oPasile",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "ShahRukhKhan",
#                         "indices": [
#                             4,
#                             17
#                         ]
#                     },
#                     {
#                         "text": "LataMangeshkar",
#                         "indices": [
#                             36,
#                             51
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/0A9oPasile",
#                         "expanded_url": "https://tribuneindia.com/news/trending/no-shah-rukh-khan-did-not-spit-near-lata-mangeshkars-mortal-remains-he-read-dua-and-blew-the-air-367807",
#                         "display_url": "tribuneindia.com/news/trending/\u2026",
#                         "indices": [
#                             101,
#                             124
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 3046490198,
#                 "id_str": "3046490198",
#                 "name": "The Tribune",
#                 "screen_name": "thetribunechd",
#                 "location": "Chandigarh",
#                 "description": "Official Twitter handle of The Tribune, North India\u2019s oldest and most trusted newspaper, published from Chandigarh, India. https://t.co/QQ5bS8UQEL",
#                 "url": "https://t.co/F40Xqlm0K3",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/F40Xqlm0K3",
#                                 "expanded_url": "http://www.tribuneindia.com",
#                                 "display_url": "tribuneindia.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/QQ5bS8UQEL",
#                                 "expanded_url": "http://facebook.com/TheTribuneChd",
#                                 "display_url": "facebook.com/TheTribuneChd",
#                                 "indices": [
#                                     123,
#                                     146
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 143634,
#                 "friends_count": 313,
#                 "listed_count": 585,
#                 "created_at": "Fri Feb 27 12:48:01 +0000 2015",
#                 "favourites_count": 109,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 268056,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "ABB8C2",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme4/bg.gif",
#                 "profile_background_tile": true,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/571293278281007104/a9uLp3Ae_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/571293278281007104/a9uLp3Ae_normal.jpeg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/3046490198/1633020591",
#                 "profile_link_color": "3B94D9",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 108,
#             "favorite_count": 445,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 108,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Mon Feb 07 21:02:59 +0000 2022",
#         "id": 1490793233567612929,
#         "id_str": "1490793233567612929",
#         "text": "RT @SamarHamdani5: #ShahRukhKhan\n\nYou don't have the right to be called a man, if you not have respect for a woman.\"\nMen who love their mot\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "ShahRukhKhan",
#                     "indices": [
#                         19,
#                         32
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "SamarHamdani5",
#                     "name": "Samar Hamdani",
#                     "id": 152010553,
#                     "id_str": "152010553",
#                     "indices": [
#                         3,
#                         17
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 3404616673,
#             "id_str": "3404616673",
#             "name": "GR !! SADIA !! AM\u2764",
#             "screen_name": "sadia_199525",
#             "location": "MUSICAL WORLD \ud83c\udfa4\ud83c\udfb9",
#             "description": "A simple FAN GIRL. From the smallest part of world. Love to listening songs. @GuruOfficial & @AmaalMallik slaying my world.\ud83d\ude07",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1005,
#             "friends_count": 198,
#             "listed_count": 6,
#             "created_at": "Mon Aug 31 14:30:27 +0000 2015",
#             "favourites_count": 23862,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 75010,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1490380476477210624/MOS-so9p_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1490380476477210624/MOS-so9p_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3404616673/1589321770",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 20:50:53 +0000 2022",
#             "id": 1490790188381093891,
#             "id_str": "1490790188381093891",
#             "text": "#ShahRukhKhan\n\nYou don't have the right to be called a man, if you not have respect for a woman.\"\nMen who love thei\u2026 https://t.co/SpvU5BvhE3",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "ShahRukhKhan",
#                         "indices": [
#                             0,
#                             13
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/SpvU5BvhE3",
#                         "expanded_url": "https://twitter.com/i/web/status/1490790188381093891",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 152010553,
#                 "id_str": "152010553",
#                 "name": "Samar Hamdani",
#                 "screen_name": "SamarHamdani5",
#                 "location": "Lahore, Pakistan",
#                 "description": "actor/ former producer at @capitaltv &  DOCTOR OF PHYSIO THERAPY AT FATIMA MEMORIAL INSTITUE LAHORE\nActor / Writer / Content creator",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 219,
#                 "friends_count": 316,
#                 "listed_count": 0,
#                 "created_at": "Fri Jun 04 21:02:48 +0000 2010",
#                 "favourites_count": 1844,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 2505,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": true,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1282154577056477185/zKf06boz_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1282154577056477185/zKf06boz_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/152010553/1492959537",
#                 "profile_link_color": "0084B4",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 4,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     }
# ]
