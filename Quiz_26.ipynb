# %% [markdown]
# <a href="https://colab.research.google.com/github/ovisaha5/DataProcessingSP22/blob/main/Quiz_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Quiz 26
# ###Many Distribution
# ###Avijit Saha

# %%
import pandas as pa
import seaborn as sns
import matplotlib.pyplot as plt
df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

# %%
ax = sns.boxplot(data = df, y = 'calories')
ax.set_title('Box plot of Calories')
plt.show()

# %%
ax = sns.boxplot(data = df, x= 'workout_type', y = 'calories')
ax.set_title('Box plot of Calories')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
plt.show()

# %%
sns.boxplot(data = df, x = 'calories', y= 'workout_type', color='yellow')
sns.stripplot(data = df, x = 'calories', y= 'workout_type', color='black')
